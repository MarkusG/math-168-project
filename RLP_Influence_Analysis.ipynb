# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def open_line_file(filename):
    with open(f'./Rapid_Transit_Lines/{filename}.txt', 'r') as f:
      lines = f.readlines()
    return lines

line_files = [
    'Red-C1-0',
    'Red-C1-1',
    'Red-C2-0',
    'Red-C2-1',
    'Green-B-C1-0',
    'Green-B-C1-1',
    'Green-C-C1-0',
    'Green-C-C1-1',
    'Green-D-C1-0',
    'Green-D-C1-1',
    'Green-E-C1-0',
    'Green-E-C1-1',
    'Orange-C1-0',
    'Orange-C1-1',
    'Blue-C1-0',
    'Blue-C1-1'
]

line_stations = map(open_line_file, line_files)

stations = set()
edges = set()

for line in line_stations:
    for i in range(len(line)-1):
        stop_name = line[i].rstrip()
        next_stop_name = line[i+1].rstrip()
        stations.add(stop_name)
        edges.add((stop_name, next_stop_name))
    end_stop_name = line[-1].rstrip()
    stations.add(end_stop_name)

network = nx.Graph()
network.add_nodes_from(stations)
network.add_edges_from(edges)

fig = plt.figure(figsize = (10,10))
layout = nx.kamada_kawai_layout(network)
nx.draw(network, layout, node_size=50)

# %%
NL = list(network)
NL
# Out:
# ['Assembly',
#  'Fenway',
#  'Mission Park',
#  'Reservoir',
#  'Brookline Village',
#  'Kendall/MIT',
#  'Airport',
#  'Museum of Fine Arts',
#  'Boylston',
#  'Northeastern University',
#  'Saint Paul Street',
#  'Magoun Square',
#  'Arlington',
#  'Tappan Street',
#  'Ball Square',
#  'Savin Hill',
#  'Union Square',
#  'Griggs Street',
#  'Riverway',
#  'Chinatown',
#  'Suffolk Downs',
#  'Downtown Crossing',
#  'East Somerville',
#  'Malden Center',
#  'Brigham Circle',
#  'North Quincy',
#  'Englewood Avenue',
#  'Maverick',
#  'Community College',
#  'South Street',
#  'Davis',
#  'Ashmont',
#  'Kent Street',
#  'Copley',
#  'Massachusetts Avenue',
#  'Brandon Hall',
#  'Broadway',
#  'Revere Beach',
#  'Medford/Tufts',
#  'Andrew',
#  'Boston University East',
#  'Blandford Street',
#  'Chestnut Hill Avenue',
#  'Haymarket',
#  'South Station',
#  'Washington Square',
#  'Alewife',
#  'Porter',
#  'Charles/MGH',
#  'Babcock Street',
#  'Beachmont',
#  'Bowdoin',
#  'Jackson Square',
#  'Government Center',
#  'Back Bay',
#  'Hynes Convention Center',
#  'Boston University Central',
#  'Waban',
#  'Back of the Hill',
#  'Sutherland Road',
#  'Ruggles',
#  'Quincy Center',
#  'Allston Street',
#  'Washington Street',
#  'Warren Street',
#  'Shawmut',
#  'Wellington',
#  'Prudential',
#  'Forest Hills',
#  'Fairbanks Street',
#  'North Station',
#  'Woodland',
#  'Lechmere',
#  'Orient Heights',
#  'Wollaston',
#  'Wood Island',
#  'Amory Street',
#  'JFK/UMass',
#  'Dean Road',
#  'Summit Avenue',
#  'Coolidge Corner',
#  'Riverside',
#  'Fenwood Road',
#  'Quincy Adams',
#  'Heath Street',
#  'Wonderland',
#  'Symphony',
#  'Oak Grove',
#  'Newton Highlands',
#  "Saint Mary's Street",
#  'Newton Centre',
#  'Fields Corner',
#  'Science Park/West End',
#  'Longwood Medical Area',
#  'Eliot',
#  'Chiswick Road',
#  'Brookline Hills',
#  "Packard's Corner",
#  'Gilman Square',
#  'Park Street',
#  'Braintree',
#  'Harvard',
#  'Green Street',
#  'Chestnut Hill',
#  'Aquarium',
#  'Central',
#  'Boston College',
#  'State',
#  'Hawes Street',
#  'Longwood',
#  'Beaconsfield',
#  'Tufts Medical Center',
#  'Harvard Avenue',
#  'Roxbury Crossing',
#  'Kenmore',
#  'Sullivan Square',
#  'Stony Brook',
#  'Cleveland Circle']

# %%
def station_id_to_index(station_id_list):
    """
    Will get a list of the indices of your stations in the node list
    :param station_id_list: the stop id of your stations
    :return: the list of the indices correlated with the stop id in node list
    """
    NL_indices = []

    for id in station_id_list:
        NL_indices.append((id, NL.index(id)))

    return NL_indices


def index_to_station_id(index_list):
    """
    Will get a list of the station id of your index in the node list
    :param index_list: the list of indices
    :return: the list of station id's correlated to node list
    """
    station_list = []

    for i in index_list:
        station_list.append(NL[i])

    return station_list


def rlp(f, adjacency, epsilon, max_l=3):
    """
    Implementing the RLP algorithm into python
    :param f: 1xN vector, components corresponding to target nodes are 1 and 0 otherwise
    :param adjacency: NxN adjacecny matrix of our network
    :param epsilon: tunable parameter controlling weight of the paths with different lengths
    :param max_l: furthest nodes we consider
    :return: 1xN vector that ranks the importance of nodes on our network
    """
    s_rlp = np.zeros(len(f))

    for l in range(0, max_l):
        summation_iteration = np.power(epsilon, l) * f @ np.linalg.matrix_power(adjacency, l + 1)
        s_rlp = np.add(s_rlp, summation_iteration)

    return s_rlp


def get_ranked_stations(array):
    """
    Take the ranking and convert the numbers to stations
    :param array: the calculated stations
    :return: the station's that are important
    """

    def merge(list1, list2):
        merged_list = [(list1[i], list2[i]) for i in range(0, len(list1))]
        return merged_list

    indices = list(np.nonzero(array)[1])

    values = []
    for i in indices:
        values.append(array[0][i])

    stations = index_to_station_id(indices)

    # Create list of tuples (station, value of station)
    merged = merge(stations, values)
    # Sort on values
    merged.sort(key=lambda x: x[1], reverse = True)

    # Grab first element of each tuple
    station_sorted = (list(zip(*merged))[0])

    return station_sorted

# %%
# Concert/Stadium cluster of nodes (Crypto arena, stadiums near USC, dodger stadium)
print(f"TD Garden - North Station, index {NL.index('North Station')}")
print(f"Big Night Live - North Station, index {NL.index('North Station')}")
print(f"Fenway Park - Kenmore, index {NL.index('Kenmore')}")
print(f"Harvard Stadium - Harvard Ave, index {NL.index('Harvard')}")

Destination_station_ids = ['North Station', 'Kenmore', 'Harvard']
# Out:
# TD Garden - North Station, index 70
# Big Night Live - North Station, index 70
# Fenway Park - Kenmore, index 114
# Harvard Stadium - Harvard Ave, index 101

# %%
# For Concert/Stadium Stations

# get f
f = np.zeros((1,len(NL)))
busy_station_indices = station_id_to_index(Destination_station_ids)
for i in busy_station_indices:
    f[0][i[1]] = 1
    
# Get adjacency matrix
A_stadium = nx.adjacency_matrix(network)
A_stadium = A_stadium.toarray()

# epsilon
epsilon = 0.1


# Calculate
get_ranked_stations(rlp(f, A_stadium, epsilon, 3))
# Out:
# ('Fenway',
#  'Blandford Street',
#  'Haymarket',
#  'Hynes Convention Center',
#  "Saint Mary's Street",
#  'Community College',
#  'Science Park/West End',
#  'Porter',
#  'Central',
#  'Kenmore',
#  'North Station',
#  'Harvard',
#  'Government Center',
#  'State',
#  'Kendall/MIT',
#  'Davis',
#  'Copley',
#  'Boston University East',
#  'Lechmere',
#  'Hawes Street',
#  'Longwood',
#  'Sullivan Square',
#  'Assembly',
#  'Brookline Village',
#  'Arlington',
#  'Union Square',
#  'Downtown Crossing',
#  'East Somerville',
#  'Kent Street',
#  'Alewife',
#  'Charles/MGH',
#  'Bowdoin',
#  'Boston University Central',
#  'Prudential',
#  'Park Street',
#  'Aquarium')

# %% [markdown]
# # Ok Now Onto the New Stuff
#
# Let's figure out how to get delay data working...

# %%
import json

# %%
delays_file = open("./Delay_Data/named_rapid_transit_delays.json", 'r')
delays_json = delays_file.read()
delays_file.close()

delays = json.loads(delays_json)
fig, ax = plt.subplots()
hist = ax.hist(delays.values(), bins=100)

# %%
# remove outliers
delays = dict((s, d) for s, d in delays.items() if d > -5000)

fig, ax = plt.subplots()
hist = ax.hist(delays.values(), bins=100)

# %%
nx.set_node_attributes(network, delays, "avg_delay")

# proof of concept for coloring nodes; for now just split into positive and negative delays
# later we can split into bins
nonnegative_delay_nodes = [n for (n, delay) in nx.get_node_attributes(network, "avg_delay").items() if delay >= 0]
negative_delay_nodes = [n for (n, delay) in nx.get_node_attributes(network, "avg_delay").items() if delay < 0]
remaining_nodes = list(set(network.nodes()) - set(nonnegative_delay_nodes) - set(negative_delay_nodes))

fig = plt.figure(figsize = (10,10))
layout = nx.kamada_kawai_layout(network)
nx.draw_networkx_nodes(network, layout, nodelist=nonnegative_delay_nodes, node_color='red', node_size=50)
nx.draw_networkx_nodes(network, layout, nodelist=negative_delay_nodes, node_color='green', node_size=50)
nx.draw_networkx_nodes(network, layout, nodelist=remaining_nodes, node_color='blue', node_size=50)
nx.draw_networkx_edges(network, layout)

# %% [markdown]
# ## Weighted edges

# %%
network.edges()
# Out:
# EdgeView([('Assembly', 'Sullivan Square'), ('Assembly', 'Wellington'), ('Fenway', 'Longwood'), ('Fenway', 'Kenmore'), ('Mission Park', 'Fenwood Road'), ('Mission Park', 'Riverway'), ('Reservoir', 'Chestnut Hill'), ('Reservoir', 'Beaconsfield'), ('Brookline Village', 'Longwood'), ('Brookline Village', 'Brookline Hills'), ('Kendall/MIT', 'Charles/MGH'), ('Kendall/MIT', 'Central'), ('Airport', 'Wood Island'), ('Airport', 'Maverick'), ('Museum of Fine Arts', 'Longwood Medical Area'), ('Museum of Fine Arts', 'Northeastern University'), ('Boylston', 'Arlington'), ('Boylston', 'Park Street'), ('Northeastern University', 'Symphony'), ('Saint Paul Street', 'Coolidge Corner'), ('Saint Paul Street', 'Kent Street'), ('Magoun Square', 'Ball Square'), ('Magoun Square', 'Gilman Square'), ('Arlington', 'Copley'), ('Tappan Street', 'Washington Square'), ('Tappan Street', 'Dean Road'), ('Ball Square', 'Medford/Tufts'), ('Savin Hill', 'Fields Corner'), ('Savin Hill', 'JFK/UMass'), ('Union Square', 'Lechmere'), ('Griggs Street', 'Allston Street'), ('Griggs Street', 'Harvard Avenue'), ('Riverway', 'Back of the Hill'), ('Chinatown', 'Tufts Medical Center'), ('Chinatown', 'Downtown Crossing'), ('Suffolk Downs', 'Beachmont'), ('Suffolk Downs', 'Orient Heights'), ('Downtown Crossing', 'South Station'), ('Downtown Crossing', 'State'), ('Downtown Crossing', 'Park Street'), ('East Somerville', 'Lechmere'), ('East Somerville', 'Gilman Square'), ('Malden Center', 'Wellington'), ('Malden Center', 'Oak Grove'), ('Brigham Circle', 'Fenwood Road'), ('Brigham Circle', 'Longwood Medical Area'), ('North Quincy', 'JFK/UMass'), ('North Quincy', 'Wollaston'), ('Englewood Avenue', 'Dean Road'), ('Englewood Avenue', 'Cleveland Circle'), ('Maverick', 'Aquarium'), ('Community College', 'Sullivan Square'), ('Community College', 'North Station'), ('South Street', 'Chestnut Hill Avenue'), ('South Street', 'Boston College'), ('Davis', 'Alewife'), ('Davis', 'Porter'), ('Ashmont', 'Shawmut'), ('Kent Street', 'Hawes Street'), ('Copley', 'Prudential'), ('Copley', 'Hynes Convention Center'), ('Massachusetts Avenue', 'Back Bay'), ('Massachusetts Avenue', 'Ruggles'), ('Brandon Hall', 'Summit Avenue'), ('Brandon Hall', 'Fairbanks Street'), ('Broadway', 'South Station'), ('Broadway', 'Andrew'), ('Revere Beach', 'Beachmont'), ('Revere Beach', 'Wonderland'), ('Andrew', 'JFK/UMass'), ('Boston University East', 'Boston University Central'), ('Boston University East', 'Blandford Street'), ('Blandford Street', 'Kenmore'), ('Chestnut Hill Avenue', 'Chiswick Road'), ('Haymarket', 'Government Center'), ('Haymarket', 'State'), ('Haymarket', 'North Station'), ('Washington Square', 'Fairbanks Street'), ('Porter', 'Harvard'), ('Charles/MGH', 'Park Street'), ('Babcock Street', 'Amory Street'), ('Babcock Street', "Packard's Corner"), ('Bowdoin', 'Government Center'), ('Jackson Square', 'Stony Brook'), ('Jackson Square', 'Roxbury Crossing'), ('Government Center', 'Park Street'), ('Government Center', 'State'), ('Back Bay', 'Tufts Medical Center'), ('Hynes Convention Center', 'Kenmore'), ('Boston University Central', 'Amory Street'), ('Waban', 'Eliot'), ('Waban', 'Woodland'), ('Back of the Hill', 'Heath Street'), ('Sutherland Road', 'Chiswick Road'), ('Sutherland Road', 'Washington Street'), ('Ruggles', 'Roxbury Crossing'), ('Quincy Center', 'Wollaston'), ('Quincy Center', 'Quincy Adams'), ('Allston Street', 'Warren Street'), ('Washington Street', 'Warren Street'), ('Shawmut', 'Fields Corner'), ('Prudential', 'Symphony'), ('Forest Hills', 'Green Street'), ('North Station', 'Science Park/West End'), ('Woodland', 'Riverside'), ('Lechmere', 'Science Park/West End'), ('Orient Heights', 'Wood Island'), ('Summit Avenue', 'Coolidge Corner'), ('Quincy Adams', 'Braintree'), ('Newton Highlands', 'Eliot'), ('Newton Highlands', 'Newton Centre'), ("Saint Mary's Street", 'Hawes Street'), ("Saint Mary's Street", 'Kenmore'), ('Newton Centre', 'Chestnut Hill'), ('Brookline Hills', 'Beaconsfield'), ("Packard's Corner ...

# %%
dict_of_delay = nx.get_node_attributes(network, "avg_delay")

def get_delay(node_name, attribute_dict = dict_of_delay):
    try:
      attribute_val = attribute_dict[node_name]
    except:
      attribute_val = 0
    return attribute_val

# %%
get_delay('Assembly', dict_of_delay)
# Out:
# 70.1666666666667

# %%
def open_line_file(filename):
    with open(f'./Rapid_Transit_Lines/{filename}.txt', 'r') as f:
      lines = f.readlines()
    return lines

line_files = [
    'Red-C1-0',
    'Red-C1-1',
    'Red-C2-0',
    'Red-C2-1',
    'Green-B-C1-0',
    'Green-B-C1-1',
    'Green-C-C1-0',
    'Green-C-C1-1',
    'Green-D-C1-0',
    'Green-D-C1-1',
    'Green-E-C1-0',
    'Green-E-C1-1',
    'Orange-C1-0',
    'Orange-C1-1',
    'Blue-C1-0',
    'Blue-C1-1'
]

line_stations = map(open_line_file, line_files)

stations = set()
edges = set()

network2 = nx.Graph()

for line in line_stations:
    for i in range(len(line)-1):
        stop_name = line[i].rstrip()
        next_stop_name = line[i+1].rstrip()
        stations.add(stop_name)
        w = 0.5*(get_delay(stop_name, dict_of_delay) + get_delay(next_stop_name, dict_of_delay))
        if w < 0:
            w=0
        network2.add_edge(stop_name, next_stop_name, weight = w)   
    end_stop_name = line[-1].rstrip()
    stations.add(end_stop_name)


network2.add_nodes_from(stations)


fig = plt.figure(figsize = (10,10))
layout = nx.kamada_kawai_layout(network2)
nx.draw(network2, layout, node_size=50)
# Out:
# /usr/lib/python3.11/site-packages/networkx/drawing/layout.py:724: RuntimeWarning: divide by zero encountered in divide
#   costargs = (np, 1 / (dist_mtx + np.eye(dist_mtx.shape[0]) * 1e-3), meanwt, dim)

# %%
network2.edges(data=True)
# Out:
# EdgeDataView([('Alewife', 'Davis', {'weight': 230.375}), ('Davis', 'Porter', {'weight': 488.675}), ('Porter', 'Harvard', {'weight': 473.1}), ('Harvard', 'Central', {'weight': 383.6}), ('Central', 'Kendall/MIT', {'weight': 307.63333333333355}), ('Kendall/MIT', 'Charles/MGH', {'weight': 301.166666666667}), ('Charles/MGH', 'Park Street', {'weight': 0}), ('Park Street', 'Downtown Crossing', {'weight': 0}), ('Park Street', 'Government Center', {'weight': 0}), ('Park Street', 'Boylston', {'weight': 0}), ('Downtown Crossing', 'South Station', {'weight': 61.5714285714285}), ('Downtown Crossing', 'State', {'weight': 28.6964285714285}), ('Downtown Crossing', 'Chinatown', {'weight': 105.14285714285705}), ('South Station', 'Broadway', {'weight': 0.0}), ('Broadway', 'Andrew', {'weight': 0.0}), ('Andrew', 'JFK/UMass', {'weight': 0.0}), ('JFK/UMass', 'North Quincy', {'weight': 29.0}), ('JFK/UMass', 'Savin Hill', {'weight': 0.0}), ('North Quincy', 'Wollaston', {'weight': 98.5}), ('Wollaston', 'Quincy Center', {'weight': 267.0}), ('Quincy Center', 'Quincy Adams', {'weight': 416.0}), ('Quincy Adams', 'Braintree', {'weight': 218.5}), ('Savin Hill', 'Fields Corner', {'weight': 0.0}), ('Fields Corner', 'Shawmut', {'weight': 0.0}), ('Shawmut', 'Ashmont', {'weight': 0.0}), ('Government Center', 'Haymarket', {'weight': 0}), ('Government Center', 'State', {'weight': 0}), ('Government Center', 'Bowdoin', {'weight': 0}), ('Boylston', 'Arlington', {'weight': 0}), ('Arlington', 'Copley', {'weight': 0}), ('Copley', 'Hynes Convention Center', {'weight': 0}), ('Copley', 'Prudential', {'weight': 0}), ('Hynes Convention Center', 'Kenmore', {'weight': 0}), ('Kenmore', 'Blandford Street', {'weight': 0}), ('Kenmore', "Saint Mary's Street", {'weight': 61.75}), ('Kenmore', 'Fenway', {'weight': 0}), ('Blandford Street', 'Boston University East', {'weight': 0}), ('Boston University East', 'Boston University Central', {'weight': 0}), ('Boston University Central', 'Amory Street', {'weight': 0}), ('Amory Street', 'Babcock Street', {'weight': 0}), ('Babcock Street', "Packard's Corner", {'weight': 0}), ("Packard's Corner", 'Harvard Avenue', {'weight': 0}), ('Harvard Avenue', 'Griggs Street', {'weight': 0}), ('Griggs Street', 'Allston Street', {'weight': 0}), ('Allston Street', 'Warren Street', {'weight': 0}), ('Warren Street', 'Washington Street', {'weight': 0}), ('Washington Street', 'Sutherland Road', {'weight': 0}), ('Sutherland Road', 'Chiswick Road', {'weight': 0}), ('Chiswick Road', 'Chestnut Hill Avenue', {'weight': 0}), ('Chestnut Hill Avenue', 'South Street', {'weight': 0}), ('South Street', 'Boston College', {'weight': 0}), ("Saint Mary's Street", 'Hawes Street', {'weight': 95.5}), ('Hawes Street', 'Kent Street', {'weight': 96.0}), ('Kent Street', 'Saint Paul Street', {'weight': 82.0}), ('Saint Paul Street', 'Coolidge Corner', {'weight': 55.5}), ('Coolidge Corner', 'Summit Avenue', {'weight': 30.5}), ('Summit Avenue', 'Brandon Hall', {'weight': 26.0}), ('Brandon Hall', 'Fairbanks Street', {'weight': 47.5}), ('Fairbanks Street', 'Washington Square', {'weight': 58.0}), ('Washington Square', 'Tappan Street', {'weight': 53.5}), ('Tappan Street', 'Dean Road', {'weight': 50.0}), ('Dean Road', 'Englewood Avenue', {'weight': 26.5}), ('Englewood Avenue', 'Cleveland Circle', {'weight': 15.0}), ('Union Square', 'Lechmere', {'weight': 0}), ('Lechmere', 'Science Park/West End', {'weight': 0}), ('Lechmere', 'East Somerville', {'weight': 0}), ('Science Park/West End', 'North Station', {'weight': 0}), ('North Station', 'Haymarket', {'weight': 0}), ('North Station', 'Community College', {'weight': 0}), ('Haymarket', 'State', {'weight': 0}), ('Fenway', 'Longwood', {'weight': 0}), ('Longwood', 'Brookline Village', {'weight': 0}), ('Brookline Village', 'Brookline Hills', {'weight': 0}), ('Brookline Hills', 'Beaconsfield', {'weight': 0}), ('Beaconsfield', 'Reservoir', {'weight': 0}), ('Reservoir', 'Chestnut Hill', {'weight': 0}), ('Chestnut Hill', 'Newton Centre', {'weight': 0}), (' ...

# %% [markdown]
# ## OK lets see if this works

# %%
def normalize_graph(G):
    
    # Get list of old edge weights
    old_edge_weights = [data['weight'] for node1, node2, data in G.edges(data=True)]
    # Calculate mean of old edge weights
    mean_old_edge_weights = sum(old_edge_weights)/len(old_edge_weights)
    
    # importing Statistics module
    import statistics
    # Calculate standard deviation of old edge weights
    stdev_old_edge_weights = statistics.stdev(old_edge_weights)
    
    # Create new graph we will add edges to 
    new_G = nx.Graph()
    new_G.add_nodes_from(list(G))
    for node1, node2, data in G.edges(data=True):
        # Z-score
        std_weight = (data['weight'] - mean_old_edge_weights)/stdev_old_edge_weights
        # New standard deviation of: std_weight/5
        std_weight = std_weight/5
        # New mean of 1
        std_weight = std_weight + 1

        # if less than 0, turn to 0
        if std_weight < 0:
            std_weight = 0
            
        # Add new weights to new graph
        new_G.add_edge(node1, node2, weight = std_weight)
        
    return new_G

# %%
network3 = normalize_graph(network2)

# %%
network3.edges(data=True)
# Out:
# EdgeDataView([('Alewife', 'Davis', {'weight': 1.4026130044371174}), ('Davis', 'Porter', {'weight': 1.946429391300573}), ('Porter', 'Harvard', {'weight': 1.9136382948027089}), ('Harvard', 'Central', {'weight': 1.7252079168535053}), ('Central', 'Kendall/MIT', {'weight': 1.56527017705975}), ('Kendall/MIT', 'Charles/MGH', {'weight': 1.5516554681874426}), ('Charles/MGH', 'Park Street', {'weight': 0.9175890008611646}), ('Park Street', 'Downtown Crossing', {'weight': 0.9175890008611646}), ('Park Street', 'Government Center', {'weight': 0.9175890008611646}), ('Park Street', 'Boylston', {'weight': 0.9175890008611646}), ('Downtown Crossing', 'South Station', {'weight': 1.047219476353753}), ('Downtown Crossing', 'State', {'weight': 0.9780055246768807}), ('Downtown Crossing', 'Chinatown', {'weight': 1.138953339521362}), ('South Station', 'Broadway', {'weight': 0.9175890008611646}), ('Broadway', 'Andrew', {'weight': 0.9175890008611646}), ('Andrew', 'JFK/UMass', {'weight': 0.9175890008611646}), ('JFK/UMass', 'North Quincy', {'weight': 0.9786446540514093}), ('JFK/UMass', 'Savin Hill', {'weight': 0.9175890008611646}), ('North Quincy', 'Wollaston', {'weight': 1.1249676849728578}), ('Wollaston', 'Quincy Center', {'weight': 1.4797220836816938}), ('Quincy Center', 'Quincy Adams', {'weight': 1.7934218190384685}), ('Quincy Adams', 'Braintree', {'weight': 1.377611767139388}), ('Savin Hill', 'Fields Corner', {'weight': 0.9175890008611646}), ('Fields Corner', 'Shawmut', {'weight': 0.9175890008611646}), ('Shawmut', 'Ashmont', {'weight': 0.9175890008611646}), ('Government Center', 'Haymarket', {'weight': 0.9175890008611646}), ('Government Center', 'State', {'weight': 0.9175890008611646}), ('Government Center', 'Bowdoin', {'weight': 0.9175890008611646}), ('Boylston', 'Arlington', {'weight': 0.9175890008611646}), ('Arlington', 'Copley', {'weight': 0.9175890008611646}), ('Copley', 'Hynes Convention Center', {'weight': 0.9175890008611646}), ('Copley', 'Prudential', {'weight': 0.9175890008611646}), ('Hynes Convention Center', 'Kenmore', {'weight': 0.9175890008611646}), ('Kenmore', 'Blandford Street', {'weight': 0.9175890008611646}), ('Kenmore', "Saint Mary's Street", {'weight': 1.0475954348093581}), ('Kenmore', 'Fenway', {'weight': 0.9175890008611646}), ('Blandford Street', 'Boston University East', {'weight': 0.9175890008611646}), ('Boston University East', 'Boston University Central', {'weight': 0.9175890008611646}), ('Boston University Central', 'Amory Street', {'weight': 0.9175890008611646}), ('Amory Street', 'Babcock Street', {'weight': 0.9175890008611646}), ('Babcock Street', "Packard's Corner", {'weight': 0.9175890008611646}), ("Packard's Corner", 'Harvard Avenue', {'weight': 0.9175890008611646}), ('Harvard Avenue', 'Griggs Street', {'weight': 0.9175890008611646}), ('Griggs Street', 'Allston Street', {'weight': 0.9175890008611646}), ('Allston Street', 'Warren Street', {'weight': 0.9175890008611646}), ('Warren Street', 'Washington Street', {'weight': 0.9175890008611646}), ('Washington Street', 'Sutherland Road', {'weight': 0.9175890008611646}), ('Sutherland Road', 'Chiswick Road', {'weight': 0.9175890008611646}), ('Chiswick Road', 'Chestnut Hill Avenue', {'weight': 0.9175890008611646}), ('Chestnut Hill Avenue', 'South Street', {'weight': 0.9175890008611646}), ('South Street', 'Boston College', {'weight': 0.9175890008611646}), ("Saint Mary's Street", 'Hawes Street', {'weight': 1.1186515829186947}), ('Hawes Street', 'Kent Street', {'weight': 1.1197042665943886}), ('Kent Street', 'Saint Paul Street', {'weight': 1.0902291236749602}), ('Saint Paul Street', 'Coolidge Corner', {'weight': 1.0344368888631847}), ('Coolidge Corner', 'Summit Avenue', {'weight': 0.981802705078491}), ('Summit Avenue', 'Brandon Hall', {'weight': 0.9723285519972461}), ('Brandon Hall', 'Fairbanks Street', {'weight': 1.0175939500520828}), ('Fairbanks Street', 'Washington Square', {'weight': 1.0397003072416542}), ('Washington Square', 'Tappan Street', {'weight': 1.0302261541604092}), ('T ...

# %% [markdown]
# ## Ok lets see if our formula works on it...

# %%
# For Concert/Stadium Stations

# get f
f = np.zeros((1,len(NL)))
busy_station_indices = station_id_to_index(Destination_station_ids)
for i in busy_station_indices:
    f[0][i[1]] = 1
    
# Get adjacency matrix
A_stadium = nx.adjacency_matrix(network)
A_stadium = A_stadium.toarray()

# epsilon
epsilon = 0.1


# Calculate
get_ranked_stations(rlp(f, A_stadium, epsilon, 3))
# Out:
# ('Fenway',
#  'Blandford Street',
#  'Haymarket',
#  'Hynes Convention Center',
#  "Saint Mary's Street",
#  'Community College',
#  'Science Park/West End',
#  'Porter',
#  'Central',
#  'Kenmore',
#  'North Station',
#  'Harvard',
#  'Government Center',
#  'State',
#  'Kendall/MIT',
#  'Davis',
#  'Copley',
#  'Boston University East',
#  'Lechmere',
#  'Hawes Street',
#  'Longwood',
#  'Sullivan Square',
#  'Assembly',
#  'Brookline Village',
#  'Arlington',
#  'Union Square',
#  'Downtown Crossing',
#  'East Somerville',
#  'Kent Street',
#  'Alewife',
#  'Charles/MGH',
#  'Bowdoin',
#  'Boston University Central',
#  'Prudential',
#  'Park Street',
#  'Aquarium')

# %%
# proof of concept for coloring nodes; for now just split into positive and negative delays
# later we can split into bins
ranked = list(get_ranked_stations(rlp(f, A_stadium, epsilon, 3)))
important_stations = list(get_ranked_stations(rlp(f, A_stadium, epsilon, 3)))
remaining_nodes = list(set(network.nodes()) - set(important_stations))
stations = [stop for stop in ranked if stop in ['North Station', 'Kenmore', 'Harvard']]

fig = plt.figure(figsize=(10, 10))
layout = nx.kamada_kawai_layout(network)
nx.draw_networkx_nodes(network, layout, nodelist=important_stations, node_color='red', node_size=50)
nx.draw_networkx_nodes(network, layout, nodelist=remaining_nodes, node_color='blue', node_size=50)
nx.draw_networkx_nodes(network, layout, nodelist=stations, node_color='black', node_size=50)

nx.draw_networkx_edges(network, layout)
